# %% [markdown]
# ## Read data from file

# %%
import os
import codecs
def readfile(filename):
	#current_path=os.path.abspath(os.curdir)
	file_path=os.path.join("/content/drive/My Drive/SML_P1",filename)
	if not os.path.exists(file_path):
		print("error:file not found:"+filename)
		return ""
	f=codecs.open(file_path,"r","utf-8")
	s=f.read()
	f.close()
	return s
test_data=readfile("test-public.txt")
test_data=test_data.splitlines()
print("length of testing data:"+str(len(test_data)))
train_data=readfile("train.txt")
train_data=train_data.splitlines()
print("length of training data:"+str(len(train_data)))
# Out:
# length of testing data:2001
# length of training data:20000

# %% [markdown]
# ## preprocessing data

# %%
## training data

min_num=99999
max_num=0
train_list=[]
num_set=set()
i=1
for temp_str in train_data[0:1]:
  temp=temp_str.split('\t')
  num_set.add(temp[0])
  if int(temp[0])<min_num:
    min_num=int(temp[0])
  if int(temp[0])>max_num:
    max_num=int(temp[0]) 
  for j in range(1,len(temp)):
    temp_list=[]
    temp_list.append(int(temp[0]))
    temp_list.append(int(temp[j]))
    train_list.append(temp_list)
    i=i+1

    num_set.add(temp[j])
    if int(temp[j])<min_num:
      min_num=int(temp[j])
    if int(temp[j])>max_num:
      max_num=int(temp[j]) 
print("preprocessed training data length:"+str(len(train_list)))
# Out:
# preprocessed training data length:143

# %%
print(list(num_set)[0:20])
print(len(list(num_set)))
# Out:
# ['141083', '289918', '4208653', '1537559', '1411138', '1274046', '2763417', '746711', '1840280', '2404108', '151344', '1313296', '641925', '3712732', '2770509', '2673351', '2757277', '3011333', '1737397', '2451654']
# 144

# %%
print(train_list[0:20])
# Out:
# [[540762, 1912140], [540762, 1537559], [540762, 3091331], [540762, 2757277], [540762, 3237295], [540762, 1070876], [540762, 4008078], [540762, 1824878], [540762, 1005927], [540762, 2703564], [540762, 2519640], [540762, 3370407], [540762, 3883660], [540762, 2173241], [540762, 1726071], [540762, 2451654], [540762, 3906434], [540762, 2635670], [540762, 3294915], [540762, 2763417]]

# %% [markdown]
# ## Graph

# %%
import networkx as nx
G = nx.Graph()

# %%
 G.add_nodes_from(list(num_set))

# %%
G.add_edges_from(train_list)

# %%
G.number_of_nodes()
# Out:
# 288

# %%
G.number_of_edges()
# Out:
# 143

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
nx.draw(G, with_labels=True)

# %%
G.adj
# Out:
# AdjacencyView({'141083': {}, '289918': {}, '4208653': {}, '1537559': {}, '1411138': {}, '1274046': {}, '2763417': {}, '746711': {}, '1840280': {}, '2404108': {}, '151344': {}, '1313296': {}, '641925': {}, '3712732': {}, '2770509': {}, '2673351': {}, '2757277': {}, '3011333': {}, '1737397': {}, '2451654': {}, '193736': {}, '4267183': {}, '4075641': {}, '1169783': {}, '94742': {}, '952976': {}, '3386592': {}, '892512': {}, '4316209': {}, '3906434': {}, '1005927': {}, '3237295': {}, '3294915': {}, '2862019': {}, '1726071': {}, '695775': {}, '4008078': {}, '2173241': {}, '2152173': {}, '1392121': {}, '1124524': {}, '540762': {}, '2464827': {}, '3314815': {}, '557514': {}, '3662772': {}, '1818911': {}, '3118623': {}, '738638': {}, '1436216': {}, '1070876': {}, '3091331': {}, '141067': {}, '1655093': {}, '4366854': {}, '2492020': {}, '3994838': {}, '3206499': {}, '2881471': {}, '343833': {}, '1892251': {}, '2800259': {}, '1927780': {}, '3541155': {}, '3912913': {}, '2183328': {}, '1521082': {}, '851113': {}, '3142255': {}, '3586135': {}, '2737722': {}, '3562621': {}, '2463912': {}, '1970076': {}, '3767319': {}, '3043': {}, '1116703': {}, '2345899': {}, '581535': {}, '2558493': {}, '4762204': {}, '3316576': {}, '3056533': {}, '3980998': {}, '2299939': {}, '1199298': {}, '1594907': {}, '4582129': {}, '333573': {}, '400117': {}, '4467395': {}, '2672578': {}, '2989624': {}, '977117': {}, '69174': {}, '1157186': {}, '3886121': {}, '2635670': {}, '4241326': {}, '1209171': {}, '299865': {}, '1912140': {}, '2703564': {}, '3367669': {}, '3670190': {}, '3575966': {}, '2335027': {}, '3201437': {}, '3349332': {}, '1327933': {}, '1003239': {}, '1312847': {}, '611426': {}, '3370407': {}, '1853195': {}, '415955': {}, '3820661': {}, '267263': {}, '3532986': {}, '261881': {}, '4286284': {}, '4131275': {}, '1824878': {}, '4361289': {}, '661185': {}, '3133671': {}, '1436562': {}, '4575690': {}, '3704614': {}, '4313335': {}, '1462439': {}, '1719625': {}, '3702208': {}, '381025': {}, '3883660': {}, '4174165': {}, '3521384': {}, '2329535': {}, '2163471': {}, '506428': {}, '2519640': {}, '3766535': {}, '4230834': {}, '4818002': {}, 540762: {1912140: {}, 1537559: {}, 3091331: {}, 2757277: {}, 3237295: {}, 1070876: {}, 4008078: {}, 1824878: {}, 1005927: {}, 2703564: {}, 2519640: {}, 3370407: {}, 3883660: {}, 2173241: {}, 1726071: {}, 2451654: {}, 3906434: {}, 2635670: {}, 3294915: {}, 2763417: {}, 1116703: {}, 261881: {}, 2404108: {}, 3521384: {}, 2299939: {}, 2989624: {}, 4361289: {}, 3314815: {}, 3367669: {}, 641925: {}, 2862019: {}, 1274046: {}, 4316209: {}, 2463912: {}, 3043: {}, 952976: {}, 3532986: {}, 415955: {}, 4366854: {}, 267263: {}, 1199298: {}, 1840280: {}, 581535: {}, 4241326: {}, 4267183: {}, 2881471: {}, 2737722: {}, 4286284: {}, 333573: {}, 1594907: {}, 3056533: {}, 2163471: {}, 3712732: {}, 2672578: {}, 1209171: {}, 1003239: {}, 4818002: {}, 3201437: {}, 1892251: {}, 2800259: {}, 141083: {}, 2558493: {}, 1655093: {}, 4313335: {}, 738638: {}, 3702208: {}, 1124524: {}, 1436216: {}, 3206499: {}, 1462439: {}, 2345899: {}, 4131275: {}, 1169783: {}, 2152173: {}, 4174165: {}, 141067: {}, 3118623: {}, 1521082: {}, 3912913: {}, 299865: {}, 193736: {}, 3562621: {}, 94742: {}, 2464827: {}, 1719625: {}, 557514: {}, 1313296: {}, 2329535: {}, 3662772: {}, 3980998: {}, 695775: {}, 381025: {}, 3349332: {}, 3704614: {}, 1392121: {}, 3767319: {}, 1157186: {}, 4230834: {}, 1411138: {}, 1312847: {}, 1818911: {}, 3820661: {}, 1927780: {}, 400117: {}, 1853195: {}, 3994838: {}, 1327933: {}, 3386592: {}, 3766535: {}, 343833: {}, 4582129: {}, 892512: {}, 3316576: {}, 3011333: {}, 2673351: {}, 746711: {}, 2770509: {}, 3670190: {}, 4208653: {}, 1970076: {}, 2183328: {}, 2492020: {}, 289918: {}, 1436562: {}, 2335027: {}, 3133671: {}, 977117: {}, 851113: {}, 4467395: {}, 611426: {}, 3142255: {}, 4575690: {}, 3575966: {}, 661185: {}, 3541155: {}, 4762204: {}, 4075641: {}, 69174: {}, 506428: {}, 151344: {}, 3586135: {}, 3886121: {}, 1737397: {}}, 1912140: {540762: {}},  ...
